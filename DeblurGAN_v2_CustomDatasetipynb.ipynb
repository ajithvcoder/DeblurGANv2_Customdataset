# %% [markdown]
# ### Colab NoteBook DeblurGANv2 on Custom data
# Dataset link - https://drive.google.com/file/d/1Mk99lU3zJgBkBpHTl0PigJ3UiSX4yyKB/view?usp=sharing

# %% [markdown]
# Dataset download

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Mk99lU3zJgBkBpHTl0PigJ3UiSX4yyKB' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1Mk99lU3zJgBkBpHTl0PigJ3UiSX4yyKB" -O 'Licenseplate_blur_clear_dataset.zip' && rm -rf /tmp/cookies.txt
# Out:
# --2023-05-07 05:43:10--  https://docs.google.com/uc?export=download&confirm=t&id=1Mk99lU3zJgBkBpHTl0PigJ3UiSX4yyKB
# Resolving docs.google.com (docs.google.com)... 142.251.10.139, 142.251.10.100, 142.251.10.113, ...
# Connecting to docs.google.com (docs.google.com)|142.251.10.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-50-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/cao35sml818ck27bui4f0i2kukblau5c/1683438150000/12164758996825312632/*/1Mk99lU3zJgBkBpHTl0PigJ3UiSX4yyKB?e=download&uuid=3f80690c-fed1-4a32-9066-04918456110c [following]
# ...
# --2023-05-07 05:43:10--  https://doc-0c-50-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/cao35sml818ck27bui4f0i2kukblau5c/1683438150000/12164758996825312632/*/1Mk99lU3zJgBkBpHTl0PigJ3UiSX4yyKB?e=download&uuid=3f80690c-fed1-4a32-9066-04918456110c
# ...

# %%
# !unzip Licenseplate_blur_clear_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/106.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/107.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/108.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/109.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/11.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/110.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/111.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/112.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/113.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/114.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/115.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/116.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/117.jpg
#   inflating: Licenseplate_blur_clear_dataset/test/sharp/118.jpg
# ...

# %%
# !git clone https://github.com/ajithvallabai/DeblurGANv2_Customdataset.git
# Out:
# Cloning into 'DeblurGANv2'...
# remote: Enumerating objects: 902, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 902 (delta 151), reused 149 (delta 149), pack-reused 628
# Receiving objects: 100% (902/902), 66.04 MiB | 16.53 MiB/s, done.
# Resolving deltas: 100% (479/479), done.

# %%
cd DeblurGANv2_Customdataset/
# Out:
# /content/DeblurGANv2

# %%
# !pip install glog
# !pip install tensorboardX
# !pip install pretrainedmodels
# !pip install albumentations==1.2.1
# !pip install fire
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python-gflags: filename=python_gflags-3.1.2-py3-none-any.whl size=57386 sha256=f16a92dbf8b8b0db4e1fe100528111302e202213a201e130f65d259f1f97a9d2
#   Stored in directory: /root/.cache/pip/wheels/0d/7d/a2/e858f0632653a3c752a807f85a39ca9d7ed75796c62845e66c
# Successfully built python-gflags
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# #### Train
# Make sure dataset path is correct in config/config.yaml

# %%
# !python train.py
# Out:
# W0507 05:46:04.413213 1314 warnings.py:109] /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/dropout/cutout.py:50: FutureWarning: Cutout has been deprecated. Please use CoarseDropout
#   warnings.warn(
#
# I0507 05:46:04.418832 1314 dataset.py:28] Subsampling buckets from 0 to 90.0, total buckets number is 100
# I0507 05:46:04.424413 1314 dataset.py:71] Dataset has been created with 1640 samples
# I0507 05:46:04.428673 1314 dataset.py:28] Subsampling buckets from 90.0 to 100, total buckets number is 100
# I0507 05:46:04.429565 1314 dataset.py:71] Dataset has been created with 54 samples
# W0507 05:46:04.430942 1314 warnings.py:109] /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
#
# ...

# %% [markdown]
# Copy your models to drive so that no need to train again

# %%
# !mkdir saved_models

# %%
# !cp best_fpn.h5 saved_models/

# %%
# !cp last_fpn.h5 saved_models/

# %%
# !zip -r saved_models.zip saved_models
# Out:
#   adding: saved_models/ (stored 0%)
#   adding: saved_models/best_fpn.h5 (deflated 7%)
#   adding: saved_models/last_fpn.h5 (deflated 7%)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp saved_models.zip /content/gdrive/MyDrive/Blogs_dataset/

# %%
# !python predict.py -i ./test_img -o ./submit -m ./saved_models/best_fpn.h5
